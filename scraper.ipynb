# %%
import re
import time
import pandas as pd

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service 
from selenium.webdriver.support.ui import WebDriverWait

# %%
service = Service('/Your_path/chromedriver_linux64/chromedriver')
driver = webdriver.Chrome(service=Service())
wait = WebDriverWait(driver, 10)

# %%
pattern = r'\((.*?)\)'
search_url = 'https://www.imdb.com/chart/toptv/?ref_=nv_tvv_250'

# %%
ul_class_name = 'ipc-metadata-list ipc-metadata-list--dividers-between sc-a1e81754-0 eBRbsI compact-list-view ipc-metadata-list--base'
li_class_name = 'ipc-metadata-list-summary-item sc-10233bc-0 iherUv cli-parent'
title_class_name = 'ipc-title__text'
type_class_name = 'sc-b189961a-3 hidKPx cli-title-type-data'
review_class_name = 'ipc-rating-star--voteCount'
rating_class_name = 'ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb ratingGroup--imdb-rating'

# %%
driver.get(search_url)
time.sleep(30)

# %%
tv_shows = []

while True:
    # Get the HTML content of the page
    content = driver.page_source
    soup = BeautifulSoup(content, 'html.parser')

    # Find the main element containing the list of TV shows
    shows_element = soup.find('ul', attrs={'class': ul_class_name})
    li_elements = shows_element.findAll('li', attrs={'class': li_class_name})
    
    print(f"Number of shows found: {len(li_elements)}")
    
    # Loop through each list item to extract data
    for li in li_elements:
        
        # Extract the title of the show
        title_element = li.find('h3', attrs={'class': title_class_name})
        title = title_element.get_text() if title_element else 'N/A'

        # Extract the type of the show (e.g., TV series, miniseries)
        type_element = li.find('span', attrs={'class': type_class_name })
        show_type = type_element.get_text() if type_element else 'N/A'

        # Extract the review count and use regex to clean it
        review_count_element = li.find('span', attrs={'class': review_class_name})
        review = review_count_element.get_text()
        match = re.search(pattern, review)
        review_count = match.group(1) if match else 'N/A'

        # Extract the rating of the show
        rating_element = li.find('span', attrs={'class': rating_class_name})
        rating = rating_element['aria-label'] if type_element else 'N/A'

        # Store the extracted data in a dictionary
        show_data = {
            'title': title,
            'show_type': show_type,
            'rating': rating,
            'review_count': review_count,
        }

        # Print and append the show data
        print(show_data)
        tv_shows.append(show_data)
    
    driver.close()
    break

print("Scraping completed.")
# Out:
# Number of shows found: 250
# {'title': '1. Breaking Bad', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.5', 'review_count': '2.2M'}
# {'title': '2. Planet Earth II', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 9.5', 'review_count': '160K'}
# {'title': '3. Planet Earth', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 9.4', 'review_count': '222K'}
# {'title': '4. Band of Brothers', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 9.4', 'review_count': '535K'}
# {'title': '5. Chernobyl', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 9.3', 'review_count': '881K'}
# {'title': '6. The Wire', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.3', 'review_count': '382K'}
# {'title': '7. Avatar: The Last Airbender', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.3', 'review_count': '380K'}
# {'title': '8. Blue Planet II', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 9.3', 'review_count': '47K'}
# {'title': '9. The Sopranos', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.2', 'review_count': '481K'}
# {'title': '10. Cosmos: A Spacetime Odyssey', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 9.2', 'review_count': '130K'}
# {'title': '11. Cosmos', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 9.3', 'review_count': '45K'}
# {'title': '12. Our Planet', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.3', 'review_count': '52K'}
# {'title': '13. Game of Thrones', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.2', 'review_count': '2.3M'}
# {'title': '14. The World at War', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.2', 'review_count': '30K'}
# {'title': '15. Bluey', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.4', 'review_count': '30K'}
# {'title': '16. Fullmetal Alchemist: Brotherhood', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.1', 'review_count': '201K'}
# {'title': '17. Rick and Morty', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.1', 'review_count': '612K'}
# {'title': '18. Life', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 9.1', 'review_count': '43K'}
# {'title': '19. The Last Dance', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 9.1', 'review_count': '155K'}
# {'title': '20. The Twilight Zone', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.1', 'review_count': '95K'}
# {'title': '21. Sherlock', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.1', 'review_count': '1M'}
# {'title': '22. The Vietnam War', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 9.1', 'review_count': '28K'}
# {'title': '23. Attack on Titan', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.1', 'review_count': '532K'}
# {'title': '24. Batman: The Animated Series', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.0', 'review_count': '119K'}
# {'title': '25. The Office', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.0', 'review_count': '726K'}
# {'title': '26. The Blue Planet', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.0', 'review_count': '43K'}
# {'title': '27. Arcane', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.0', 'review_count': '280K'}
# {'title': '28. Better Call Saul', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.0', 'review_count': '662K'}
# {'title': '29. Scam 1992: The Harshad Mehta Story', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 9.2', 'review_count': '159K'}
# {'title': "30. Clarkson's Farm", 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.0', 'review_count': '62K'}
# {'title': '31. Human Planet', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 9.0', 'review_count': '28K'}
# {'title': '32. Frozen Planet', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 9.0', 'review_count': '33K'}
# {'title': '33. Firefly', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.9', 'review_count': '283K'}
# {'title': '34. Hunter x Hunter', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.0', 'review_count': '140K'}
# {'title': '35. Only Fools and Horses', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.0', 'review_count': '57K'}
# {'title': '36. The Civil War', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 9.0', 'review_count': '19K'}
# {'title': '37. Death Note', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.9', 'review_count': '386K'}
# {'title': '38. Seinfeld', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.9', 'review_count': '355K'}
# {'title': '39. Dekalog', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.9', 'review_count': '28K'}
# {'title': '40. The Beatles: Get Back', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.9', 'review_count': '29K'}
# {'title': '41. Gravity Falls', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.9', 'review_count': '139K'}
# {'title': '42. True Detective', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.9', 'review_count': '664K'}
# {'title': '43. Cowboy Bebop', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.9', 'review_count': '141K'}
# {'title': '44. Persona', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.0', 'review_count': '48K'}
# {'title': '45. Fargo', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.9', 'review_count': '426K'}
# {'title': '46. Nathan for You', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.9', 'review_count': '39K'}
# {'title': '47. As If', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.0', 'review_count': '23K'}
# {'title': '48. Taskmaster', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.0', 'review_count': '20K'}
# {'title': '49. Apocalypse: The Second World War', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 9.0', 'review_count': '14K'}
# {'title': '50. When They See Us', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.8', 'review_count': '139K'}
# {'title': '51. Last Week Tonight with John Oliver', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '96K'}
# {'title': '52. Africa', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.9', 'review_count': '17K'}
# {'title': '53. Friends', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.9', 'review_count': '1.1M'}
# {'title': '54. Succession', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '281K'}
# {'title': "55. It's Always Sunny in Philadelphia", 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '255K'}
# {'title': '56. TVF Pitchers', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.1', 'review_count': '73K'}
# {'title': '57. The West Wing', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.9', 'review_count': '87K'}
# {'title': "58. Monty Python's Flying Circus", 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '79K'}
# {'title': '59. Curb Your Enthusiasm', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '150K'}
# {'title': '60. Das Boot', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.8', 'review_count': '34K'}
# {'title': '61. One Piece', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.0', 'review_count': '246K'}
# {'title': "62. Frieren: Beyond Journey's End", 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.9', 'review_count': '20K'}
# {'title': '63. BoJack Horseman', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '193K'}
# {'title': '64. Fawlty Towers', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '101K'}
# {'title': "65. X-Men '97", 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.9', 'review_count': '31K'}
# {'title': '66. Leyla and Mecnun', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.1', 'review_count': '97K'}
# {'title': '67. Pride and Prejudice', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.8', 'review_count': '93K'}
# {'title': '68. Freaks and Geeks', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '154K'}
# {'title': '69. Blackadder Goes Forth', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '57K'}
# {'title': '70. Dragon Ball Z', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '150K'}
# {'title': '71. Twin Peaks', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '218K'}
# {'title': '72. Narcos', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '476K'}
# {'title': "73. Chappelle's Show", 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '72K'}
# {'title': '74. Dragon Ball Z', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '89K'}
# {'title': '75. Panchayat', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.0', 'review_count': '95K'}
# {'title': '76. Gullak', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.1', 'review_count': '24K'}
# {'title': '77. I, Claudius', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.8', 'review_count': '20K'}
# {'title': '78. Black Mirror', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '648K'}
# {'title': '79. Kota Factory', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.0', 'review_count': '84K'}
# {'title': '80. Vinland Saga', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '76K'}
# {'title': '81. South Park', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '409K'}
# {'title': '82. Over the Garden Wall', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.8', 'review_count': '72K'}
# {'title': '83. Ted Lasso', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '358K'}
# {'title': '84. Reply 1988', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.1', 'review_count': '12K'}
# {'title': '85. Bleach: Thousand-Year Blood War', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.0', 'review_count': '37K'}
# {'title': '86. Peaky Blinders', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '662K'}
# {'title': '87. Six Feet Under', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '151K'}
# {'title': '88. Rome', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '187K'}
# {'title': '89. Oz', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '108K'}
# {'title': '90. Steins;Gate', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '75K'}
# {'title': '91. The Last of Us', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '547K'}
# {'title': '92. Dark', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '453K'}
# {'title': '93. Fleabag', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '207K'}
# {'title': '94. Berserk', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '55K'}
# {'title': '95. Blue Eye Samurai', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '72K'}
# {'title': '96. The Shield', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '89K'}
# {'title': '97. The Boys', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '689K'}
# {'title': '98. Downton Abbey', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '227K'}
# {'title': '99. Battlestar Galactica', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '177K'}
# {'title': '100. The Simpsons', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '439K'}
# {'title': '101. Severance', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '211K'}
# {'title': '102. Mad Men', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '263K'}
# {'title': '103. House', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '523K'}
# {'title': '104. Arrested Development', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '326K'}
# {'title': '105. Peep Show', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '67K'}
# {'title': '106. One Punch Man', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '189K'}
# {'title': '107. Star Trek: The Next Generation', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '138K'}
# {'title': '108. Invincible', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '212K'}
# {'title': '109. The Adventures of Sherlock Holmes', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '24K'}
# {'title': '110. The Grand Tour', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '84K'}
# {'title': '111. Mahabharat', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.9', 'review_count': '24K'}
# {'title': '112. Stranger Things', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '1.4M'}
# {'title': '113. Shōgun', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '153K'}
# {'title': '114. Justice League Unlimited', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '21K'}
# {'title': '115. The Marvelous Mrs. Maisel', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '144K'}
# {'title': '116. Friday Night Lights', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '73K'}
# {'title': '117. Naruto: Shippuden', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '175K'}
# {'title': '118. Line of Duty', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '71K'}
# {'title': '119. Behzat Ç: An Ankara Detective Story', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.9', 'review_count': '33K'}
# {'title': '120. Top Gear', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '128K'}
# {'title': '121. 1883', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.7', 'review_count': '119K'}
# {'title': '122. Monster', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '47K'}
# {'title': '123. The Thick of It', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '26K'}
# {'title': '124. Sarabhai V/S Sarabhai', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.9', 'review_count': '18K'}
# {'title': '125. The Mandalorian', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '596K'}
# {'title': '126. How to with John Wilson', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '14K'}
# {'title': '127. Aspirants', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.2', 'review_count': '313K'}
# {'title': '128. This Is Us', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '161K'}
# {'title': '129. Father Ted', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '44K'}
# {'title': '130. House of Cards', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '534K'}
# {'title': '131. Atlanta', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '89K'}
# {'title': '132. Parks and Recreation', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '291K'}
# {'title': '133. Code Geass', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '82K'}
# {'title': '134. Deadwood', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '119K'}
# {'title': '135. The X-Files', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '252K'}
# {'title': '136. The Crown', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '260K'}
# {'title': '137. Dexter', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '780K'}
# {'title': '138. Primal', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '22K'}
# {'title': '139. Adventure Time', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '114K'}
# {'title': "140. It's a Sin", 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.6', 'review_count': '37K'}
# {'title': '141. Ramayan', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.0', 'review_count': '24K'}
# {'title': '142. The Bridge', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '78K'}
# {'title': '143. Daredevil', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '479K'}
# {'title': '144. Blackadder II', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '50K'}
# {'title': '145. Lonesome Dove', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.7', 'review_count': '26K'}
# {'title': '146. The Jinx: The Life and Deaths of Robert Durst', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '53K'}
# {'title': '147. Mindhunter', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '342K'}
# {'title': '148. Haikyu!!', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '37K'}
# {'title': '149. Poirot', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '53K'}
# {'title': '150. The Return of Sherlock Holmes', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '14K'}
# {'title': '151. Mr. Bean', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '135K'}
# {'title': '152. The Offer', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.6', 'review_count': '41K'}
# {'title': '153. Crash Landing on You', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '43K'}
# {'title': '154. Gomorrah', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '45K'}
# {'title': '155. Mr Inbetween', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '32K'}
# {'title': '156. Pose', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '33K'}
# {'title': '157. Scavengers Reign', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.7', 'review_count': '20K'}
# {'title': '158. Critical Role', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.1', 'review_count': '13K'}
# {'title': '159. Blackadder the Third', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '47K'}
# {'title': '160. Mystery Science Theater 3000', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '26K'}
# {'title': '161. Yes Minister', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '17K'}
# {'title': '162. Archer', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '167K'}
# {'title': '163. Demon Slayer: Kimetsu no Yaiba', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '158K'}
# {'title': '164. Yeh Meri Family', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.0', 'review_count': '26K'}
# {'title': '165. Anne with an E', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '68K'}
# {'title': '166. Dopesick', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.6', 'review_count': '80K'}
# {'title': '167. The Bear', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '229K'}
# {'title': '168. Young Justice', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '46K'}
# {'title': '169. Greatest Events of WWII in Colour', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.6', 'review_count': '11K'}
# {'title': '170. The Newsroom', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '126K'}
# {'title': '171. Boardwalk Empire', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '205K'}
# {'title': '172. QI', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '34K'}
# {'title': '173. Yellowstone', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '228K'}
# {'title': '174. El Chavo del Ocho', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '13K'}
# {'title': '175. Justified', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '120K'}
# {'title': '176. The Bureau', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '15K'}
# {'title': '177. The Bugs Bunny Show', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '36K'}
# {'title': '178. Homicide: Life on the Street', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '14K'}
# {'title': '179. The Haunting of Hill House', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.5', 'review_count': '293K'}
# {'title': '180. What We Do in the Shadows', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '105K'}
# {'title': '181. Dragon Ball', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '67K'}
# {'title': '182. Justice League', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '52K'}
# {'title': '183. The Venture Bros.', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '28K'}
# {'title': '184. Battlestar Galactica', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.5', 'review_count': '81K'}
# {'title': '185. The Family Man', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '100K'}
# {'title': '186. Dragon Ball', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '66K'}
# {'title': "187. The Queen's Gambit", 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.5', 'review_count': '566K'}
# {'title': '188. Flight of the Conchords', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '66K'}
# {'title': '189. Jujutsu Kaisen', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '124K'}
# {'title': '190. Yes, Prime Minister', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '13K'}
# {'title': '191. Endeavour', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '34K'}
# {'title': '192. Making a Murderer', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '103K'}
# {'title': '193. Coupling', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '48K'}
# {'title': '194. Samurai Champloo', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '56K'}
# {'title': '195. Rocket Boys', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.9', 'review_count': '18K'}
# {'title': '196. The IT Crowd', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '166K'}
# {'title': '197. Mr. Robot', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '422K'}
# {'title': '198. Impractical Jokers', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '46K'}
# {'title': '199. Ezel', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '38K'}
# {'title': '200. Black Sun', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.8', 'review_count': '13K'}
# {'title': '201. Spaced', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '58K'}
# {'title': '202. The Eric Andre Show', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '22K'}
# {'title': "203. I'm Alan Partridge", 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '22K'}
# {'title': '204. Samurai Jack', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '60K'}
# {'title': '205. Detectorists', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '22K'}
# {'title': '206. Long Way Round', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.6', 'review_count': '15K'}
# {'title': '207. Mob Psycho 100', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '47K'}
# {'title': '208. Happy Valley', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '66K'}
# {'title': '209. Louie', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '82K'}
# {'title': '210. Spartacus', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '259K'}
# {'title': '211. Whose Line Is It Anyway?', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '47K'}
# {'title': '212. Sons of Anarchy', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '327K'}
# {'title': '213. Through the Wormhole', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '18K'}
# {'title': '214. The Office', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '124K'}
# {'title': '215. Neon Genesis Evangelion', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '87K'}
# {'title': '216. Formula 1: Drive to Survive', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '52K'}
# {'title': '217. Derry Girls', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '62K'}
# {'title': '218. Regular Show', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '59K'}
# {'title': '219. Twin Peaks', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '77K'}
# {'title': '220. Trailer Park Boys', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '51K'}
# {'title': '221. Shameless', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '291K'}
# {'title': '222. Heartstopper', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '78K'}
# {'title': '223. Spartacus: Gods of the Arena', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.5', 'review_count': '147K'}
# {'title': '224. Skam', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '39K'}
# {'title': '225. North & South', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '35K'}
# {'title': '226. Brass Eye', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '12K'}
# {'title': "227. Schitt's Creek", 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '149K'}
# {'title': '228. Silicon Valley', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '167K'}
# {'title': '229. Futurama', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '263K'}
# {'title': '230. Fullmetal Alchemist', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '79K'}
# {'title': '231. Letterkenny', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '30K'}
# {'title': '232. Doctor Who', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '250K'}
# {'title': '233. Rurouni Kenshin: Trust and Betrayal', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.6', 'review_count': '16K'}
# {'title': '234. The Expanse', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '175K'}
# {'title': '235. Extraordinary Attorney Woo', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '28K'}
# {'title': '236. Hannibal', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '279K'}
# {'title': '237. From the Earth to the Moon', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.6', 'review_count': '13K'}
# {'title': '238. My Brilliant Friend', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '18K'}
# {'title': '239. Alchemy of Souls', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '18K'}
# {'title': '240. Avrupa Yakasi', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '22K'}
# {'title': '241. Wentworth', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '25K'}
# {'title': '242. Umbre', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '12K'}
# {'title': '243. The Rehearsal', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '27K'}
# {'title': '244. Westworld', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '537K'}
# {'title': '245. Your Lie in April', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '39K'}
# {'title': '246. Community', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.5', 'review_count': '296K'}
# {'title': '247. Gintama', 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.7', 'review_count': '16K'}
# {'title': '248. Tear Along the Dotted Line', 'show_type': 'TV Mini Series', 'rating': 'IMDb rating: 8.6', 'review_count': '15K'}
# {'title': '249. Sapne Vs Everyone', 'show_type': 'TV Series', 'rating': 'IMDb rating: 9.4', 'review_count': '68K'}
# {'title': "250. Foyle's War", 'show_type': 'TV Series', 'rating': 'IMDb rating: 8.6', 'review_count': '19K'}
# Scraping completed.

# %%
pd.DataFrame(tv_shows).to_csv('movies.csv', index=False)

# %% [markdown]
# Try below code.

# %%
def xpath_soup(element):
    components = []
    target = element if element.name else element.parent
    for node in (target, *target.parents)[-2::-1]:
        tag = '%s:%s' % (node.prefix, node.name) if node.prefix else node.name
        siblings = node.parent.find_all(tag, recursive=False)
        components.append(tag if len(siblings) == 1 else '%s[%d]' % (tag, next(
            index
            for index, sibling in enumerate(siblings, 1)
            if sibling is node
            )))
    return '/%s' % '/'.join(components)

# %%
tv_shows = []


while True:
 
    content = driver.page_source
    soup = BeautifulSoup(content, 'html.parser')
    shows_element = soup.find('ul', attrs={'class': ul_class_name})

    li_elements = shows_element.findAll('li', attrs={'class': li_class_name})
    
    print(f"Number of shows found: {len(li_elements)}")
    
    j = 1
    for li in li_elements:
        try:
            driver.execute_script("window.scrollBy(0, 200);")

            title_element = li.find('h3', attrs={'class': title_class_name})
            title = title_element.get_text() if title_element else 'N/A'

            type_element = li.find('span', attrs={'class': type_class_name})
            show_type = type_element.get_text() if type_element else 'N/A'

            review_count_element = li.find('span', attrs={'class': review_class_name})
            review = review_count_element.get_text()
            
       
            match = re.search(pattern, review)
            review_count = match.group(1) if match else 'N/A'

            # Clicking on the show button
            show_button_xpath = f'/html/body/div[2]/main/div/div[3]/section/div/div[2]/div/ul/li[{j}]/div[3]/button'
            driver.find_element(By.XPATH, show_button_xpath).click()
            time.sleep(10)

            # Parsing popup content
            content = driver.page_source
            soup_popup = BeautifulSoup(content, 'html.parser')
            show_popup = soup_popup.find('div', attrs={'class': 'ipc-promptable-base__focus-lock'})
            
            rating_element = show_popup.find('span', attrs={'class': 'ipc-rating-star ipc-rating-star--baseAlt ipc-rating-star--imdb btp_rt_ds'})
            rating = rating_element.get_text() if rating_element else 'N/A'

            creator_element = show_popup.find('a', attrs={'class': 'ipc-link ipc-link--baseAlt sc-9bca7e5d-0 ktChvQ'})
            creator = creator_element.get_text() if creator_element else 'N/A'

            show_data = {
                'title': title,
                'show_type': show_type,
                'review_count': review_count,
                'creator': creator,
                'rating': rating
            }

            print(show_data)
            tv_shows.append(show_data)

            # Closing the popup
            close_btn = soup_popup.find('button', attrs={'class': 'ipc-icon-button ipc-icon-button--baseAlt ipc-icon-button--onBase'})
            xpath_close_btn = xpath_soup(close_btn)
            driver.find_element(By.XPATH, xpath_close_btn).click()
            time.sleep(5)

            j += 1
        except Exception as e:
            continue
    break

print("Scraping completed.")

# %%
pd.DataFrame(tv_shows).to_csv('movies.csv', index=False)
